# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from imLIBS import *

# %%
path = './data/mereni_Cu.csv'

# %%
data = read_libs(path)

# %%
size = get_size(data)
matrix = np.zeros(size)

# %%
for x,y,z in zip(data.x, data.y, data.z):
    matrix[y-1, x-1] = z

# %%
plt.imshow(matrix, cmap='jet')

# %%
export(matrix)
# Out:
#             0           1           2           3           4           5   \
# 0   191.176412  144.338187  217.268312  182.352372  155.160346  189.663492
# 1   203.422137  180.131677  211.058547  188.092016  227.095128  156.385651
# 2   212.222224  185.179277  156.364913  246.614272  166.476174  169.514282
# 3   191.492179  185.987282  179.598284  127.003298  173.006420  235.523746
# 4   153.411089  163.647851  158.417540  201.027046  188.317554  186.974553
# 5   210.061950  116.718917  190.660217  146.985673  190.247784  158.376199
# 6   252.638174  130.138314  192.417280  171.160242  169.730027  174.401705
# 7   174.450707  116.972858  139.817503  198.015873  150.995159  172.782461
# 8   118.557009  130.644540  135.257133  137.611212  138.498441  158.582667
# 9   147.368175  119.312766  155.691972  143.946099  141.364951  145.057019
# 10  154.150846  107.731795  122.676131  124.209571  123.033406  128.636565
# ...
